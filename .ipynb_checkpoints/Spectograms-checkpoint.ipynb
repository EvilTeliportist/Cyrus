# %%
import matplotlib.pyplot as plt
from scipy import signal
from scipy.io import wavfile
import os
import numpy as np

for filename in os.listdir('buffers/'):
    if filename.endswith(".wav"):
        print(filename)
        sample_rate, samples = wavfile.read('buffers/' + filename)
        frequencies, times, spectrogram = signal.spectrogram(samples, 16000)

        plt.pcolormesh(times, frequencies, spectrogram)
        plt.imshow(np.log(spectrogram))
        plt.ylabel('Frequency [Hz]')
        plt.xlabel('Time [sec]')
        plt.show()
# Out:
# 0.wav
# <ipython-input-13-f1707c26ac71>:13: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(times, frequencies, spectrogram)
# 1.wav
# 10.wav
# 11.wav
# 2.wav
# 3.wav
# 4.wav
# 5.wav
# 6.wav
# saved.wav
